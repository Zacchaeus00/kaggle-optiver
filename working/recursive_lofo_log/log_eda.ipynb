# %%
import pandas as pd
import joblib

# %%
df_list = joblib.load('lofo_dfs.pkl')
df_list[-1]
# Out:
#                          feature  importance_mean  importance_std  \
# 0                    log_return1         0.001317        0.000430
# 1                   price_spread         0.000849        0.000654
# 2            timeagg_log_return2         0.000836        0.001002
# 3   timeagg_300_trade_log_return         0.000831        0.000359
# 4              trade_order_count         0.000716        0.000496
# ..                           ...              ...             ...
# 69          volume_imbalance_150         0.000125        0.000248
# 70          volume_imbalance_300         0.000100        0.000206
# 71                   wap_balance         0.000053        0.000076
# 72                      wap1_150         0.000016        0.000064
# 73                bid_spread_300         0.000012        0.000026
#
#        val_imp_0  val_imp_1  val_imp_2  val_imp_3     val_imp_4
# 0   1.264709e-03   0.001868   0.001519   0.000560  1.372487e-03
# ...
