# %%
import pandas as pd
from imp import reload
from utils import util
reload(util)
# Out:
# <module 'utils.util' from '/Users/wanjun/Desktop/比赛训练营/Kaggle-量化比赛/code/src/utils/util.py'>

# %%
# 加载 book 数据和 trade 数据
book0 = util.load_book(0)
trade0 = util.load_trade(0)

# %%
# 加载标签数据
label = pd.read_csv('../data/train.csv')
label = label[label.stock_id==0]
label = label.sort_values('time_id').target

# %%
col_name_book = book0.columns.tolist()
col_name_trade = ['price', 'size', 'order_count', 'seconds_in_bucket']

# %%
from tsfresh import extract_features
book0 = book0.reset_index()
extracted_features_book = extract_features(book0, column_id="time_id", column_sort="index")
# Out:
# Feature Extraction: 100%|██████████| 20/20 [19:22<00:00, 58.10s/it]

# %%
#特征筛选
from tsfresh import select_features
from tsfresh.utilities.dataframe_functions import impute
from tsfresh import feature_extraction

impute(extracted_features_book)
features_filtered_book = select_features(extracted_features_book.reset_index(drop=True), label)
feature_param_book = feature_extraction.settings.from_columns(features_filtered_book)

# %%
len(features_filtered_book.columns)
# Out:
# 2490

# %%
features_filtered_book.to_csv('../data/features_filtered_book.csv')

# %%
trade0 = trade0.reset_index()
extracted_features_trade0 = extract_features(trade0[['time_id','index']+col_name_trade], column_id="time_id", column_sort="index")
# Out:
# Feature Extraction: 100%|██████████| 20/20 [04:31<00:00, 13.55s/it]

# %%
#特征筛选
from tsfresh import select_features
from tsfresh.utilities.dataframe_functions import impute
from tsfresh import feature_extraction

impute(extracted_features_trade0)
features_filtered_trade0 = select_features(extracted_features_trade0.reset_index(drop=True), label)
feature_param_trade = feature_extraction.settings.from_columns(features_filtered_trade0)
# Out:
# /Users/wanjun/anaconda/envs/python36/lib/python3.6/site-packages/tsfresh/utilities/dataframe_functions.py:172: RuntimeWarning: The columns ['order_count__fft_coefficient__attr_"real"__coeff_60'
#  'order_count__fft_coefficient__attr_"real"__coeff_61'
#  'order_count__fft_coefficient__attr_"real"__coeff_62'
#  'order_count__fft_coefficient__attr_"real"__coeff_63'
#  'order_count__fft_coefficient__attr_"real"__coeff_64'
#  'order_count__fft_coefficient__attr_"real"__coeff_65'
#  'order_count__fft_coefficient__attr_"real"__coeff_66'
#  'order_count__fft_coefficient__attr_"real"__coeff_67'
#  'order_count__fft_coefficient__attr_"real"__coeff_68'
#  'order_count__fft_coefficient__attr_"real"__coeff_69'
#  'order_count__fft_coefficient__attr_"real"__coeff_70'
#  'order_count__fft_coefficient__attr_"real"__coeff_71'
#  'order_count__fft_coefficient__attr_"real"__coeff_72'
#  'order_count__fft_coefficient__attr_"real"__coeff_73'
#  'order_count__fft_coefficient__attr_"real"__coeff_74'
#  'order_count__fft_coefficient__attr_"real"__coeff_75'
#  'order_count__fft_coefficient__attr_"real"__coeff_76'
#  'order_count__fft_coefficient__attr_"real"__coeff_77'
#  'order_count__fft_coefficient__attr_"real"__coeff_78'
#  'order_count__fft_coefficient__attr_"real"__coeff_79'
#  'order_count__fft_coefficient__attr_"real"__coeff_80'
#  'order_count__fft_coefficient__attr_"real"__coeff_81'
#  'order_count__fft_coefficient__attr_"real"__coeff_82'
#  'order_count__fft_coefficient__attr_"real"__coeff_83'
#  'order_count__fft_coefficient__attr_"real"__coeff_84'
#  'order_count__fft_coefficient__attr_"real"__coeff_85'
#  'order_count__fft_coefficient__attr_"real"__coeff_86'
#  'order_count__fft_coefficient__attr_"real"__coeff_87'
#  'order_count__fft_coefficient__attr_"real"__coeff_88'
#  'order_count__fft_coefficient__attr_"real"__coeff_89'
#  'order_count__fft_coefficient__attr_"real"__coeff_90'
#  'order_count__fft_coefficient__attr_"real"__coeff_91'
#  'order_count__fft_coefficient__attr_"real"__coeff_92'
#  'order_count__fft_coefficient__attr_"real"__coeff_93'
#  'order_count__fft_coefficient__attr_"real"__coeff_94'
#  'order_count__fft_coefficient__attr_"real"__coeff_95'
#  'order_count__fft_coefficient__attr_"real"__coeff_96'
#  'order_count__fft_coefficient__attr_"real"__coeff_97'
#  'order_count__fft_coefficient__attr_"real"__coeff_98'
#  'order_count__fft_coefficient__attr_"real"__coeff_99'
#  'order_count__fft_coefficient__attr_"imag"__coeff_60'
#  'order_count__fft_coefficient__attr_"imag"__coeff_61'
#  'order_count__fft_coefficient__attr_"imag"__coeff_62'
#  'order_count__fft_coefficient__attr_"imag"__coeff_63'
#  'order_count__fft_coefficient__attr_"imag"__coeff_64'
#  'order_count__fft_coefficient__attr_"imag"__coeff_65'
#  'order_count__fft_coefficient__attr_"imag"__coeff_66'
#  'order_count__fft_coefficient__attr_"imag"__coeff_67'
#  'order_count__fft_coefficient__attr_"imag"__coeff_68'
#  'order_count__fft_coefficient__attr_"imag"__coeff_69'
#  'order_count__fft_coefficient__attr_"imag"__coeff_70'
#  'order_count__fft_coefficient__attr_"imag"__coeff_71'
#  'order_count__fft_coefficient__attr_"imag"__coeff_72'
#  'order_count__fft_coefficient__attr_"imag"__coeff_73'
#  'order_count__fft_coefficient__attr_"imag"__coeff_74'
#  'order_count__fft_coefficient__attr_"imag"__coeff_75'
#  'order_count__fft_coefficient__attr_"imag"__coeff_76'
#  'order_count__fft_coefficient__attr_"imag"__coeff_77'
#  'order_count__fft_coefficient__attr_"imag"__coeff_78'
#  'order_count__fft_coefficient__attr_"imag"__coeff_79'
#  'order_count__fft_coefficient__attr_"imag"__coeff_80'
#  'order_count__fft_coefficient__attr_"imag"__coeff_81'
#  'order_count__fft_coefficient__attr_"imag"__coeff_82'
#  'order_count__fft_coefficient__attr_"imag"__coeff_83'
#  'order_count__fft_coefficient__attr_"imag"__coeff_84'
#  'order_count__fft_coefficient__attr_"imag"__coeff_85'
#  'order_count__fft_coefficient__attr_"imag"__coeff_86'
#  'order_count__fft_coefficient__attr_"imag"__coeff_87'
#  'order_count__fft_coefficient__attr_"imag"__coeff_88'
#  'order_count__fft_coefficient__attr_"imag"__coeff_89'
#  'order_count__fft_coefficient__attr_"imag"__coeff_90'
#  'order_count__fft_coefficient__attr_"imag"__coeff_91'
#  'order_count__fft_coefficient__attr_"imag"__coeff_92'
#  'order_count__fft_coefficient__attr_"imag"__coeff_93'
#  'order_count__fft_coefficient__attr_"imag"__coeff_94'
#  'order_count__fft_coefficient__attr_"imag"__coeff_95'
#  'order_count__fft_coefficient__attr_"imag"__coeff_96'
#  'order_count__fft_coefficient__attr_"imag"__coeff_97'
#  'order_count__fft_coefficient__attr_"imag"__coeff_98'
#  'order_count__fft_coefficient__attr_"imag"__coeff_99'
#  'order_count__fft_coefficient__attr_"abs"__coeff_60'
#  'order_count__fft_coefficient__attr_"abs"__coeff_61'
#  'order_count__fft_coefficient__attr_"abs"__coeff_62'
#  'order_count__fft_coefficient__attr_"abs"__coeff_63'
#  'order_count__fft_coefficient__attr_"abs"__coeff_64'
#  'order_count__fft_coefficient__attr_"abs"__coeff_65'
#  'order_count__fft_coefficient__attr_"abs"__coeff_66'
#  'order_count__fft_coefficient__attr_"abs"__coeff_67'
#  'order_count__fft_coefficient__attr_"abs"__coeff_68'
#  'order_count__fft_coefficient__attr_"abs"__coeff_69'
#  'order_count__fft_coefficient__attr_"abs"__coeff_70'
#  'order_count__fft_coefficient__attr_"abs"__coeff_71'
#  'order_count__fft_coefficient__attr_"abs"__coeff_72'
#  'order_count__fft_coefficient__attr_"abs"__coeff_73'
#  'order_count__fft_coefficient__attr_"abs"__coeff_74'
#  'order_count__fft_coefficient__attr_"abs"__coeff_75'
#  'order_count__fft_coefficient__attr_"abs"__coeff_76'
#  'order_count__fft_coefficient__attr_"abs"__coeff_77'
#  'order_count__fft_coefficient__attr_"abs"__coeff_78'
#  'order_count__fft_coefficient__attr_"abs"__coeff_79'
#  'order_count__fft_coefficient__attr_"abs"__coeff_80'
#  'order_count__fft_coefficient__attr_"abs"__coeff_81'
#  'order_count__fft_coefficient__attr_"abs"__coeff_82'
#  'order_count__fft_coefficient__attr_"abs"__coeff_83'
#  'order_count__fft_coefficient__attr_"abs"__coeff_84'
#  'order_count__fft_coefficient__attr_"abs"__coeff_85'
#  'order_count__fft_coefficient__attr_"abs"__coeff_86'
#  'order_count__fft_coefficient__attr_"abs"__coeff_87'
#  'order_count__fft_coefficient__attr_"abs"__coeff_88'
#  'order_count__fft_coefficient__attr_"abs"__coeff_89'
#  'order_count__fft_coefficient__attr_"abs"__coeff_90'
#  'order_count__fft_coefficient__attr_"abs"__coeff_91'
#  'order_count__fft_coefficient__attr_"abs"__coeff_92'
#  'order_count__fft_coefficient__attr_"abs"__coeff_93'
#  'order_count__fft_coefficient__attr_"abs"__coeff_94'
#  'order_count__fft_coefficient__attr_"abs"__coeff_95'
#  'order_count__fft_coefficient__attr_"abs"__coeff_96'
#  'order_count__fft_coefficient__attr_"abs"__coeff_97'
#  'order_count__fft_coefficient__attr_"abs"__coeff_98'
#  'order_count__fft_coefficient__attr_"abs"__coeff_99'
#  'order_count__fft_coefficient__attr_"angle"__coeff_60'
#  'order_count__fft_coefficient__attr_"angle"__coeff_61'
#  'order_count__fft_coefficient__attr_"angle"__coeff_62'
#  'order_count__fft_coefficient__attr_"angle"__coeff_63'
#  'order_count__fft_coefficient__attr_"angle"__coeff_64'
#  'order_count__fft_coefficient__attr_"angle"__coeff_65'
#  'order_count__fft_coefficient__attr_"angle"__coeff_66'
#  'order_count__fft_coefficient__attr_"angle"__coeff_67'
#  'order_count__fft_coefficient__attr_"angle"__coeff_68'
#  'order_count__fft_coefficient__attr_"angle"__coeff_69'
#  'order_count__fft_coefficient__attr_"angle"__coeff_70'
#  'order_count__fft_coefficient__attr_"angle"__coeff_71'
#  'order_count__fft_coefficient__attr_"angle"__coeff_72'
#  'order_count__fft_coefficient__attr_"angle"__coeff_73'
#  'order_count__fft_coefficient__attr_"angle"__coeff_74'
#  'order_count__fft_coefficient__attr_"angle"__coeff_75'
#  'order_count__fft_coefficient__attr_"angle"__coeff_76'
#  'order_count__fft_coefficient__attr_"angle"__coeff_77'
#  'order_count__fft_coefficient__attr_"angle"__coeff_78'
#  'order_count__fft_coefficient__attr_"angle"__coeff_79'
#  'order_count__fft_coefficient__attr_"angle"__coeff_80'
#  'order_count__fft_coefficient__attr_"angle"__coeff_81'
#  'order_count__fft_coefficient__attr_"angle"__coeff_82'
#  'order_count__fft_coefficient__attr_"angle"__coeff_83'
#  'order_count__fft_coefficient__attr_"angle"__coeff_84'
#  'order_count__fft_coefficient__attr_"angle"__coeff_85'
#  'order_count__fft_coefficient__attr_"angle"__coeff_86'
#  'order_count__fft_coefficient__attr_"angle"__coeff_87'
#  'order_count__fft_coefficient__attr_"angle"__coeff_88'
#  'order_count__fft_coefficient__attr_"angle"__coeff_89'
#  'order_count__fft_coefficient__attr_"angle"__coeff_90'
#  'order_count__fft_coefficient__attr_"angle"__coeff_91'
#  'order_count__fft_coefficient__attr_"angle"__coeff_92'
#  'order_count__fft_coefficient__attr_"angle"__coeff_93'
#  'order_count__fft_coefficient__attr_"angle"__coeff_94'
#  'order_count__fft_coefficient__attr_"angle"__coeff_95'
#  'order_count__fft_coefficient__attr_"angle"__coeff_96'
#  'order_count__fft_coefficient__attr_"angle"__coeff_97'
#  'order_count__fft_coefficient__attr_"angle"__coeff_98'
#  'order_count__fft_coefficient__attr_"angle"__coeff_99'
#  'order_count__query_similarity_count__query_None__threshold_0.0'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_60'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_61'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_62'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_63'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_64'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_65'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_66'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_67'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_68'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_69'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_70'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_71'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_72'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_73'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_74'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_75'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_76'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_77'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_78'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_79'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_80'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_81'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_82'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_83'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_84'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_85'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_86'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_87'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_88'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_89'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_90'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_91'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_92'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_93'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_94'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_95'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_96'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_97'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_98'
#  'seconds_in_bucket__fft_coefficient__attr_"real"__coeff_99'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_60'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_61'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_62'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_63'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_64'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_65'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_66'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_67'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_68'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_69'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_70'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_71'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_72'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_73'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_74'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_75'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_76'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_77'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_78'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_79'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_80'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_81'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_82'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_83'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_84'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_85'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_86'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_87'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_88'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_89'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_90'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_91'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_92'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_93'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_94'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_95'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_96'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_97'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_98'
#  'seconds_in_bucket__fft_coefficient__attr_"imag"__coeff_99'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_60'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_61'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_62'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_63'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_64'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_65'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_66'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_67'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_68'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_69'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_70'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_71'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_72'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_73'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_74'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_75'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_76'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_77'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_78'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_79'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_80'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_81'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_82'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_83'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_84'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_85'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_86'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_87'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_88'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_89'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_90'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_91'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_92'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_93'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_94'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_95'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_96'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_97'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_98'
#  'seconds_in_bucket__fft_coefficient__attr_"abs"__coeff_99'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_60'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_61'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_62'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_63'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_64'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_65'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_66'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_67'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_68'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_69'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_70'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_71'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_72'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_73'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_74'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_75'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_76'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_77'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_78'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_79'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_80'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_81'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_82'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_83'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_84'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_85'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_86'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_87'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_88'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_89'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_90'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_91'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_92'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_93'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_94'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_95'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_96'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_97'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_98'
#  'seconds_in_bucket__fft_coefficient__attr_"angle"__coeff_99'
#  'seconds_in_bucket__query_similarity_count__query_None__threshold_0.0'
#  'price__fft_coefficient__attr_"real"__coeff_60'
#  'price__fft_coefficient__attr_"real"__coeff_61'
#  'price__fft_coefficient__attr_"real"__coeff_62'
#  'price__fft_coefficient__attr_"real"__coeff_63'
#  'price__fft_coefficient__attr_"real"__coeff_64'
#  'price__fft_coefficient__attr_"real"__coeff_65'
#  'price__fft_coefficient__attr_"real"__coeff_66'
#  'price__fft_coefficient__attr_"real"__coeff_67'
#  'price__fft_coefficient__attr_"real"__coeff_68'
#  'price__fft_coefficient__attr_"real"__coeff_69'
#  'price__fft_coefficient__attr_"real"__coeff_70'
#  'price__fft_coefficient__attr_"real"__coeff_71'
#  'price__fft_coefficient__attr_"real"__coeff_72'
#  'price__fft_coefficient__attr_"real"__coeff_73'
#  'price__fft_coefficient__attr_"real"__coeff_74'
#  'price__fft_coefficient__attr_"real"__coeff_75'
#  'price__fft_coefficient__attr_"real"__coeff_76'
#  'price__fft_coefficient__attr_"real"__coeff_77'
#  'price__fft_coefficient__attr_"real"__coeff_78'
#  'price__fft_coefficient__attr_"real"__coeff_79'
#  'price__fft_coefficient__attr_"real"__coeff_80'
#  'price__fft_coefficient__attr_"real"__coeff_81'
#  'price__fft_coefficient__attr_"real"__coeff_82'
#  'price__fft_coefficient__attr_"real"__coeff_83'
#  'price__fft_coefficient__attr_"real"__coeff_84'
#  'price__fft_coefficient__attr_"real"__coeff_85'
#  'price__fft_coefficient__attr_"real"__coeff_86'
#  'price__fft_coefficient__attr_"real"__coeff_87'
#  'price__fft_coefficient__attr_"real"__coeff_88'
#  'price__fft_coefficient__attr_"real"__coeff_89'
#  'price__fft_coefficient__attr_"real"__coeff_90'
#  'price__fft_coefficient__attr_"real"__coeff_91'
#  'price__fft_coefficient__attr_"real"__coeff_92'
#  'price__fft_coefficient__attr_"real"__coeff_93'
#  'price__fft_coefficient__attr_"real"__coeff_94'
#  'price__fft_coefficient__attr_"real"__coeff_95'
#  'price__fft_coefficient__attr_"real"__coeff_96'
#  'price__fft_coefficient__attr_"real"__coeff_97'
#  'price__fft_coefficient__attr_"real"__coeff_98'
#  'price__fft_coefficient__attr_"real"__coeff_99'
#  'price__fft_coefficient__attr_"imag"__coeff_60'
#  'price__fft_coefficient__attr_"imag"__coeff_61'
#  'price__fft_coefficient__attr_"imag"__coeff_62'
#  'price__fft_coefficient__attr_"imag"__coeff_63'
#  'price__fft_coefficient__attr_"imag"__coeff_64'
#  'price__fft_coefficient__attr_"imag"__coeff_65'
#  'price__fft_coefficient__attr_"imag"__coeff_66'
#  'price__fft_coefficient__attr_"imag"__coeff_67'
#  'price__fft_coefficient__attr_"imag"__coeff_68'
#  'price__fft_coefficient__attr_"imag"__coeff_69'
#  'price__fft_coefficient__attr_"imag"__coeff_70'
#  'price__fft_coefficient__attr_"imag"__coeff_71'
#  'price__fft_coefficient__attr_"imag"__coeff_72'
#  'price__fft_coefficient__attr_"imag"__coeff_73'
#  'price__fft_coefficient__attr_"imag"__coeff_74'
#  'price__fft_coefficient__attr_"imag"__coeff_75'
#  'price__fft_coefficient__attr_"imag"__coeff_76'
#  'price__fft_coefficient__attr_"imag"__coeff_77'
#  'price__fft_coefficient__attr_"imag"__coeff_78'
#  'price__fft_coefficient__attr_"imag"__coeff_79'
#  'price__fft_coefficient__attr_"imag"__coeff_80'
#  'price__fft_coefficient__attr_"imag"__coeff_81'
#  'price__fft_coefficient__attr_"imag"__coeff_82'
#  'price__fft_coefficient__attr_"imag"__coeff_83'
#  'price__fft_coefficient__attr_"imag"__coeff_84'
#  'price__fft_coefficient__attr_"imag"__coeff_85'
#  'price__fft_coefficient__attr_"imag"__coeff_86'
#  'price__fft_coefficient__attr_"imag"__coeff_87'
#  'price__fft_coefficient__attr_"imag"__coeff_88'
#  'price__fft_coefficient__attr_"imag"__coeff_89'
#  'price__fft_coefficient__attr_"imag"__coeff_90'
#  'price__fft_coefficient__attr_"imag"__coeff_91'
#  'price__fft_coefficient__attr_"imag"__coeff_92'
#  'price__fft_coefficient__attr_"imag"__coeff_93'
#  'price__fft_coefficient__attr_"imag"__coeff_94'
#  'price__fft_coefficient__attr_"imag"__coeff_95'
#  'price__fft_coefficient__attr_"imag"__coeff_96'
#  'price__fft_coefficient__attr_"imag"__coeff_97'
#  'price__fft_coefficient__attr_"imag"__coeff_98'
#  'price__fft_coefficient__attr_"imag"__coeff_99'
#  'price__fft_coefficient__attr_"abs"__coeff_60'
#  'price__fft_coefficient__attr_"abs"__coeff_61'
#  'price__fft_coefficient__attr_"abs"__coeff_62'
#  'price__fft_coefficient__attr_"abs"__coeff_63'
#  'price__fft_coefficient__attr_"abs"__coeff_64'
#  'price__fft_coefficient__attr_"abs"__coeff_65'
#  'price__fft_coefficient__attr_"abs"__coeff_66'
#  'price__fft_coefficient__attr_"abs"__coeff_67'
#  'price__fft_coefficient__attr_"abs"__coeff_68'
#  'price__fft_coefficient__attr_"abs"__coeff_69'
#  'price__fft_coefficient__attr_"abs"__coeff_70'
#  'price__fft_coefficient__attr_"abs"__coeff_71'
#  'price__fft_coefficient__attr_"abs"__coeff_72'
#  'price__fft_coefficient__attr_"abs"__coeff_73'
#  'price__fft_coefficient__attr_"abs"__coeff_74'
#  'price__fft_coefficient__attr_"abs"__coeff_75'
#  'price__fft_coefficient__attr_"abs"__coeff_76'
#  'price__fft_coefficient__attr_"abs"__coeff_77'
#  'price__fft_coefficient__attr_"abs"__coeff_78'
#  'price__fft_coefficient__attr_"abs"__coeff_79'
#  'price__fft_coefficient__attr_"abs"__coeff_80'
#  'price__fft_coefficient__attr_"abs"__coeff_81'
#  'price__fft_coefficient__attr_"abs"__coeff_82'
#  'price__fft_coefficient__attr_"abs"__coeff_83'
#  'price__fft_coefficient__attr_"abs"__coeff_84'
#  'price__fft_coefficient__attr_"abs"__coeff_85'
#  'price__fft_coefficient__attr_"abs"__coeff_86'
#  'price__fft_coefficient__attr_"abs"__coeff_87'
#  'price__fft_coefficient__attr_"abs"__coeff_88'
#  'price__fft_coefficient__attr_"abs"__coeff_89'
#  'price__fft_coefficient__attr_"abs"__coeff_90'
#  'price__fft_coefficient__attr_"abs"__coeff_91'
#  'price__fft_coefficient__attr_"abs"__coeff_92'
#  'price__fft_coefficient__attr_"abs"__coeff_93'
#  'price__fft_coefficient__attr_"abs"__coeff_94'
#  'price__fft_coefficient__attr_"abs"__coeff_95'
#  'price__fft_coefficient__attr_"abs"__coeff_96'
#  'price__fft_coefficient__attr_"abs"__coeff_97'
#  'price__fft_coefficient__attr_"abs"__coeff_98'
#  'price__fft_coefficient__attr_"abs"__coeff_99'
#  'price__fft_coefficient__attr_"angle"__coeff_60'
#  'price__fft_coefficient__attr_"angle"__coeff_61'
#  'price__fft_coefficient__attr_"angle"__coeff_62'
#  'price__fft_coefficient__attr_"angle"__coeff_63'
#  'price__fft_coefficient__attr_"angle"__coeff_64'
#  'price__fft_coefficient__attr_"angle"__coeff_65'
#  'price__fft_coefficient__attr_"angle"__coeff_66'
#  'price__fft_coefficient__attr_"angle"__coeff_67'
#  'price__fft_coefficient__attr_"angle"__coeff_68'
#  'price__fft_coefficient__attr_"angle"__coeff_69'
#  'price__fft_coefficient__attr_"angle"__coeff_70'
#  'price__fft_coefficient__attr_"angle"__coeff_71'
#  'price__fft_coefficient__attr_"angle"__coeff_72'
#  'price__fft_coefficient__attr_"angle"__coeff_73'
#  'price__fft_coefficient__attr_"angle"__coeff_74'
#  'price__fft_coefficient__attr_"angle"__coeff_75'
#  'price__fft_coefficient__attr_"angle"__coeff_76'
#  'price__fft_coefficient__attr_"angle"__coeff_77'
#  'price__fft_coefficient__attr_"angle"__coeff_78'
#  'price__fft_coefficient__attr_"angle"__coeff_79'
#  'price__fft_coefficient__attr_"angle"__coeff_80'
#  'price__fft_coefficient__attr_"angle"__coeff_81'
#  'price__fft_coefficient__attr_"angle"__coeff_82'
#  'price__fft_coefficient__attr_"angle"__coeff_83'
#  'price__fft_coefficient__attr_"angle"__coeff_84'
#  'price__fft_coefficient__attr_"angle"__coeff_85'
#  'price__fft_coefficient__attr_"angle"__coeff_86'
#  'price__fft_coefficient__attr_"angle"__coeff_87'
#  'price__fft_coefficient__attr_"angle"__coeff_88'
#  'price__fft_coefficient__attr_"angle"__coeff_89'
#  'price__fft_coefficient__attr_"angle"__coeff_90'
#  'price__fft_coefficient__attr_"angle"__coeff_91'
#  'price__fft_coefficient__attr_"angle"__coeff_92'
#  'price__fft_coefficient__attr_"angle"__coeff_93'
#  'price__fft_coefficient__attr_"angle"__coeff_94'
#  'price__fft_coefficient__attr_"angle"__coeff_95'
#  'price__fft_coefficient__attr_"angle"__coeff_96'
#  'price__fft_coefficient__attr_"angle"__coeff_97'
#  'price__fft_coefficient__attr_"angle"__coeff_98'
#  'price__fft_coefficient__attr_"angle"__coeff_99'
#  'price__query_similarity_count__query_None__threshold_0.0'
#  'size__fft_coefficient__attr_"real"__coeff_60'
#  'size__fft_coefficient__attr_"real"__coeff_61'
#  'size__fft_coefficient__attr_"real"__coeff_62'
#  'size__fft_coefficient__attr_"real"__coeff_63'
#  'size__fft_coefficient__attr_"real"__coeff_64'
#  'size__fft_coefficient__attr_"real"__coeff_65'
#  'size__fft_coefficient__attr_"real"__coeff_66'
#  'size__fft_coefficient__attr_"real"__coeff_67'
#  'size__fft_coefficient__attr_"real"__coeff_68'
#  'size__fft_coefficient__attr_"real"__coeff_69'
#  'size__fft_coefficient__attr_"real"__coeff_70'
#  'size__fft_coefficient__attr_"real"__coeff_71'
#  'size__fft_coefficient__attr_"real"__coeff_72'
#  'size__fft_coefficient__attr_"real"__coeff_73'
#  'size__fft_coefficient__attr_"real"__coeff_74'
#  'size__fft_coefficient__attr_"real"__coeff_75'
#  'size__fft_coefficient__attr_"real"__coeff_76'
#  'size__fft_coefficient__attr_"real"__coeff_77'
#  'size__fft_coefficient__attr_"real"__coeff_78'
#  'size__fft_coefficient__attr_"real"__coeff_79'
#  'size__fft_coefficient__attr_"real"__coeff_80'
#  'size__fft_coefficient__attr_"real"__coeff_81'
#  'size__fft_coefficient__attr_"real"__coeff_82'
#  'size__fft_coefficient__attr_"real"__coeff_83'
#  'size__fft_coefficient__attr_"real"__coeff_84'
#  'size__fft_coefficient__attr_"real"__coeff_85'
#  'size__fft_coefficient__attr_"real"__coeff_86'
#  'size__fft_coefficient__attr_"real"__coeff_87'
#  'size__fft_coefficient__attr_"real"__coeff_88'
#  'size__fft_coefficient__attr_"real"__coeff_89'
#  'size__fft_coefficient__attr_"real"__coeff_90'
#  'size__fft_coefficient__attr_"real"__coeff_91'
#  'size__fft_coefficient__attr_"real"__coeff_92'
#  'size__fft_coefficient__attr_"real"__coeff_93'
#  'size__fft_coefficient__attr_"real"__coeff_94'
#  'size__fft_coefficient__attr_"real"__coeff_95'
#  'size__fft_coefficient__attr_"real"__coeff_96'
#  'size__fft_coefficient__attr_"real"__coeff_97'
#  'size__fft_coefficient__attr_"real"__coeff_98'
#  'size__fft_coefficient__attr_"real"__coeff_99'
#  'size__fft_coefficient__attr_"imag"__coeff_60'
#  'size__fft_coefficient__attr_"imag"__coeff_61'
#  'size__fft_coefficient__attr_"imag"__coeff_62'
#  'size__fft_coefficient__attr_"imag"__coeff_63'
#  'size__fft_coefficient__attr_"imag"__coeff_64'
#  'size__fft_coefficient__attr_"imag"__coeff_65'
#  'size__fft_coefficient__attr_"imag"__coeff_66'
#  'size__fft_coefficient__attr_"imag"__coeff_67'
#  'size__fft_coefficient__attr_"imag"__coeff_68'
#  'size__fft_coefficient__attr_"imag"__coeff_69'
#  'size__fft_coefficient__attr_"imag"__coeff_70'
#  'size__fft_coefficient__attr_"imag"__coeff_71'
#  'size__fft_coefficient__attr_"imag"__coeff_72'
#  'size__fft_coefficient__attr_"imag"__coeff_73'
#  'size__fft_coefficient__attr_"imag"__coeff_74'
#  'size__fft_coefficient__attr_"imag"__coeff_75'
#  'size__fft_coefficient__attr_"imag"__coeff_76'
#  'size__fft_coefficient__attr_"imag"__coeff_77'
#  'size__fft_coefficient__attr_"imag"__coeff_78'
#  'size__fft_coefficient__attr_"imag"__coeff_79'
#  'size__fft_coefficient__attr_"imag"__coeff_80'
#  'size__fft_coefficient__attr_"imag"__coeff_81'
#  'size__fft_coefficient__attr_"imag"__coeff_82'
#  'size__fft_coefficient__attr_"imag"__coeff_83'
#  'size__fft_coefficient__attr_"imag"__coeff_84'
#  'size__fft_coefficient__attr_"imag"__coeff_85'
#  'size__fft_coefficient__attr_"imag"__coeff_86'
#  'size__fft_coefficient__attr_"imag"__coeff_87'
#  'size__fft_coefficient__attr_"imag"__coeff_88'
#  'size__fft_coefficient__attr_"imag"__coeff_89'
#  'size__fft_coefficient__attr_"imag"__coeff_90'
#  'size__fft_coefficient__attr_"imag"__coeff_91'
#  'size__fft_coefficient__attr_"imag"__coeff_92'
#  'size__fft_coefficient__attr_"imag"__coeff_93'
#  'size__fft_coefficient__attr_"imag"__coeff_94'
#  'size__fft_coefficient__attr_"imag"__coeff_95'
#  'size__fft_coefficient__attr_"imag"__coeff_96'
#  'size__fft_coefficient__attr_"imag"__coeff_97'
#  'size__fft_coefficient__attr_"imag"__coeff_98'
#  'size__fft_coefficient__attr_"imag"__coeff_99'
#  'size__fft_coefficient__attr_"abs"__coeff_60'
#  'size__fft_coefficient__attr_"abs"__coeff_61'
#  'size__fft_coefficient__attr_"abs"__coeff_62'
#  'size__fft_coefficient__attr_"abs"__coeff_63'
#  'size__fft_coefficient__attr_"abs"__coeff_64'
#  'size__fft_coefficient__attr_"abs"__coeff_65'
#  'size__fft_coefficient__attr_"abs"__coeff_66'
#  'size__fft_coefficient__attr_"abs"__coeff_67'
#  'size__fft_coefficient__attr_"abs"__coeff_68'
#  'size__fft_coefficient__attr_"abs"__coeff_69'
#  'size__fft_coefficient__attr_"abs"__coeff_70'
#  'size__fft_coefficient__attr_"abs"__coeff_71'
#  'size__fft_coefficient__attr_"abs"__coeff_72'
#  'size__fft_coefficient__attr_"abs"__coeff_73'
#  'size__fft_coefficient__attr_"abs"__coeff_74'
#  'size__fft_coefficient__attr_"abs"__coeff_75'
#  'size__fft_coefficient__attr_"abs"__coeff_76'
#  'size__fft_coefficient__attr_"abs"__coeff_77'
#  'size__fft_coefficient__attr_"abs"__coeff_78'
#  'size__fft_coefficient__attr_"abs"__coeff_79'
#  'size__fft_coefficient__attr_"abs"__coeff_80'
#  'size__fft_coefficient__attr_"abs"__coeff_81'
#  'size__fft_coefficient__attr_"abs"__coeff_82'
#  'size__fft_coefficient__attr_"abs"__coeff_83'
#  'size__fft_coefficient__attr_"abs"__coeff_84'
#  'size__fft_coefficient__attr_"abs"__coeff_85'
#  'size__fft_coefficient__attr_"abs"__coeff_86'
#  'size__fft_coefficient__attr_"abs"__coeff_87'
#  'size__fft_coefficient__attr_"abs"__coeff_88'
#  'size__fft_coefficient__attr_"abs"__coeff_89'
#  'size__fft_coefficient__attr_"abs"__coeff_90'
#  'size__fft_coefficient__attr_"abs"__coeff_91'
#  'size__fft_coefficient__attr_"abs"__coeff_92'
#  'size__fft_coefficient__attr_"abs"__coeff_93'
#  'size__fft_coefficient__attr_"abs"__coeff_94'
#  'size__fft_coefficient__attr_"abs"__coeff_95'
#  'size__fft_coefficient__attr_"abs"__coeff_96'
#  'size__fft_coefficient__attr_"abs"__coeff_97'
#  'size__fft_coefficient__attr_"abs"__coeff_98'
#  'size__fft_coefficient__attr_"abs"__coeff_99'
#  'size__fft_coefficient__attr_"angle"__coeff_60'
#  'size__fft_coefficient__attr_"angle"__coeff_61'
#  'size__fft_coefficient__attr_"angle"__coeff_62'
#  'size__fft_coefficient__attr_"angle"__coeff_63'
#  'size__fft_coefficient__attr_"angle"__coeff_64'
#  'size__fft_coefficient__attr_"angle"__coeff_65'
#  'size__fft_coefficient__attr_"angle"__coeff_66'
#  'size__fft_coefficient__attr_"angle"__coeff_67'
#  'size__fft_coefficient__attr_"angle"__coeff_68'
#  'size__fft_coefficient__attr_"angle"__coeff_69'
#  'size__fft_coefficient__attr_"angle"__coeff_70'
#  'size__fft_coefficient__attr_"angle"__coeff_71'
#  'size__fft_coefficient__attr_"angle"__coeff_72'
#  'size__fft_coefficient__attr_"angle"__coeff_73'
#  'size__fft_coefficient__attr_"angle"__coeff_74'
#  'size__fft_coefficient__attr_"angle"__coeff_75'
#  'size__fft_coefficient__attr_"angle"__coeff_76'
#  'size__fft_coefficient__attr_"angle"__coeff_77'
#  'size__fft_coefficient__attr_"angle"__coeff_78'
#  'size__fft_coefficient__attr_"angle"__coeff_79'
#  'size__fft_coefficient__attr_"angle"__coeff_80'
#  'size__fft_coefficient__attr_"angle"__coeff_81'
#  'size__fft_coefficient__attr_"angle"__coeff_82'
#  'size__fft_coefficient__attr_"angle"__coeff_83'
#  'size__fft_coefficient__attr_"angle"__coeff_84'
#  'size__fft_coefficient__attr_"angle"__coeff_85'
#  'size__fft_coefficient__attr_"angle"__coeff_86'
#  'size__fft_coefficient__attr_"angle"__coeff_87'
#  'size__fft_coefficient__attr_"angle"__coeff_88'
#  'size__fft_coefficient__attr_"angle"__coeff_89'
#  'size__fft_coefficient__attr_"angle"__coeff_90'
#  'size__fft_coefficient__attr_"angle"__coeff_91'
#  'size__fft_coefficient__attr_"angle"__coeff_92'
#  'size__fft_coefficient__attr_"angle"__coeff_93'
#  'size__fft_coefficient__attr_"angle"__coeff_94'
#  'size__fft_coefficient__attr_"angle"__coeff_95'
#  'size__fft_coefficient__attr_"angle"__coeff_96'
#  'size__fft_coefficient__attr_"angle"__coeff_97'
#  'size__fft_coefficient__attr_"angle"__coeff_98'
#  'size__fft_coefficient__attr_"angle"__coeff_99'
#  'size__query_similarity_count__query_None__threshold_0.0'] did not have any finite values. Filling with zeros.
#   df.iloc[:, np.where(is_col_non_finite)[0]].columns.values), RuntimeWarning)

# %%
features_filtered_trade0.to_csv('../data/features_filtered_trade0.csv')

# %%
feature_all = features_filtered_book.merge(features_filtered_trade0,how='inner',left_index=True,right_index=True)

# %%
feature_all.to_csv('../data/feature_all.csv')

# %%
import numpy as np
np.save('../data/feature_param_trade.npy', feature_param_trade) 
np.save('../data/feature_param_book.npy', feature_param_book)

# %%
import numpy as np
t = np.load('../data/feature_param_trade.npy',allow_pickle = True).item()

# %%
# Out:
#         time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  \
# 0             5                  0    1.001422    1.002301    1.001370
# 1             5                  1    1.001422    1.002301    1.001370
# 2             5                  5    1.001422    1.002301    1.001370
# 3             5                  6    1.001422    1.002301    1.001370
# 4             5                  7    1.001422    1.002301    1.001370
# ...         ...                ...         ...         ...         ...
# 917548    32767                568    0.998275    0.998754    0.997796
# 917549    32767                569    0.998275    0.998754    0.997892
# 917550    32767                571    0.998275    0.998754    0.997892
# 917551    32767                572    0.998275    0.998754    0.997892
# 917552    32767                582    0.998275    0.998754    0.998179
#
#         ask_price2  bid_size1  ask_size1  bid_size2  ask_size2  stock_id
# 0         1.002353          3        226          2        100         0
# 1         1.002353          3        100          2        100         0
# 2         1.002405          3        100          2        100         0
# 3         1.002405          3        126          2        100         0
# 4         1.002405          3        126          2        100         0
# ...            ...        ...        ...        ...        ...       ...
# 917548    0.998946         90         90         48         28         0
# 917549    0.998946         91         90        200         28         0
# 917550    0.998946         91         90        100         28         0
# 917551    0.998946         92         90        100         28         0
# 917552    0.998946         92         90         26         28         0
#
# [917553 rows x 11 columns]
